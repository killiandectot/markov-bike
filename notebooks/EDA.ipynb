# %% [markdown]
# # EDA - Markov Bike

# %%
import pandas_gbq

sql_stations = """
select *
from `bigquery-public-data.new_york.citibike_stations`
LIMIT 10
"""
stations = pandas_gbq.read_gbq(sql_stations)

sql_trips = """
SELECT * 
FROM `bigquery-public-data.new_york.citibike_trips` 
LIMIT 1000
"""
trips = pandas_gbq.read_gbq(sql_trips)
# Out:
# /Users/killiandectot/.pyenv/versions/3.10.6/envs/markov-bike/lib/python3.10/site-packages/google/cloud/bigquery/table.py:2007: UserWarning: A progress bar was requested, but there was an error loading the tqdm library. Please install tqdm to use the progress bar functionality.
#   record_batch = self.to_arrow(
# /Users/killiandectot/.pyenv/versions/3.10.6/envs/markov-bike/lib/python3.10/site-packages/google/cloud/bigquery/table.py:2007: UserWarning: A progress bar was requested, but there was an error loading the tqdm library. Please install tqdm to use the progress bar functionality.
#   record_batch = self.to_arrow(

# %%
trips
# Out:
#      tripduration                 starttime                  stoptime  \
# 0             107 2014-06-06 13:02:01+00:00 2014-06-06 13:03:48+00:00
# 1            1105 2013-08-24 17:03:52+00:00 2013-08-24 17:22:17+00:00
# 2             990 2014-04-25 11:52:28+00:00 2014-04-25 12:08:58+00:00
# 3             138 2015-08-20 16:58:57+00:00 2015-08-20 17:01:16+00:00
# 4              78 2014-09-13 13:18:36+00:00 2014-09-13 13:19:54+00:00
# ..            ...                       ...                       ...
# 995           187 2014-05-12 13:54:32+00:00 2014-05-12 13:57:39+00:00
# 996           265 2014-12-01 16:41:11+00:00 2014-12-01 16:45:36+00:00
# 997           139 2013-12-30 06:27:40+00:00 2013-12-30 06:29:59+00:00
# 998           144 2014-03-10 06:39:43+00:00 2014-03-10 06:42:07+00:00
# 999           615 2015-06-18 16:29:00+00:00 2015-06-18 16:39:00+00:00
#
#      start_station_id start_station_name  start_station_latitude  \
# 0                 520    W 52 St & 5 Ave               40.759923
# 1                 520    W 52 St & 5 Ave               40.759923
# 2                 520    W 52 St & 5 Ave               40.759923
# 3                 520    W 52 St & 5 Ave               40.759923
# 4                 520    W 52 St & 5 Ave               40.759923
# ..                ...                ...                     ...
# 995               520    W 52 St & 5 Ave               40.759923
# 996               520    W 52 St & 5 Ave               40.759923
# 997               520    W 52 St & 5 Ave               40.759923
# 998               520    W 52 St & 5 Ave               40.759923
# 999               520    W 52 St & 5 Ave               40.759923
#
#      start_station_longitude  end_station_id  end_station_name  \
# 0                 -73.976485             520   W 52 St & 5 Ave
# 1                 -73.976485             520   W 52 St & 5 Ave
# 2                 -73.976485             520   W 52 St & 5 Ave
# 3                 -73.976485             520   W 52 St & 5 Ave
# 4                 -73.976485             520   W 52 St & 5 Ave
# ..                       ...             ...               ...
# 995               -73.976485             510   W 51 St & 6 Ave
# 996               -73.976485             510   W 51 St & 6 Ave
# 997               -73.976485             510   W 51 St & 6 Ave
# 998               -73.976485             510   W 51 St & 6 Ave
# 999               -73.976485             480  W 53 St & 10 Ave
#
#      end_station_latitude  end_station_longitude  bikeid    usertype  \
# 0               40.759923             -73.976485   16692  Subscriber
# 1               40.759923             -73.976485   15352    Customer
# 2               40.759923             -73.976485   20194  Subscriber
# 3               40.759923             -73.976485   21002  Subscriber
# 4               40.759923             -73.976485   19259    Customer
# ..                    ...                    ...     ...         ...
# 995             40.760660             -73.980420   15151  Subscriber
# 996             40.760660             -73.980420   16177  Subscriber
# 997             40.760660             -73.980420   16121  Subscriber
# 998             40.760660             -73.980420   19487  Subscriber
# 999             40.766697             -73.990617   18997  Subscriber
#
#      birth_year   gender
# 0          1977     male
# 1          <NA>  unknown
# 2          1973     male
# 3          1977     male
# 4          <NA>  unknown
# ..          ...      ...
# 995        1956     male
# 996        1974     male
# 997        1986     male
# 998        1986     male
# 999        1964   female
#
# [1000 rows x 15 columns]

# %%
trips.start_station_id.unique()
# Out:
# <IntegerArray>
# [520]
# Length: 1, dtype: Int64
