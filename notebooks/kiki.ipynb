# %%
from markovBike.manager.manager import Manager
from markovBike.data_source.source import database_queries, get_stations_data, get_trips_data
from markovBike.data_source.preprocess import preprocess_stations_data, preprocess_trips_data

import pandas as pd

# %%
get_trips_data("SELECT * FROM bigquery-public-data.new_york.citibike_trips ORDER BY starttime DESC LIMIT 10")
# Out:
# Bike trips table with shape (10, 15). Columns are:
#
# tripduration                             Int64
# starttime                  datetime64[ns, UTC]
# stoptime                   datetime64[ns, UTC]
# start_station_id                         Int64
# start_station_name                      object
# start_station_latitude                 float64
# start_station_longitude                float64
# end_station_id                           Int64
# end_station_name                        object
# end_station_latitude                   float64
# end_station_longitude                  float64
# bikeid                                   Int64
# usertype                                object
# birth_year                               Int64
# gender                                  object
# dtype: object
#    tripduration                 starttime                  stoptime  \
# 0          1107 2016-09-30 23:59:51+00:00 2016-10-01 00:18:18+00:00
# 1          1117 2016-09-30 23:59:28+00:00 2016-10-01 00:18:06+00:00
# 2           552 2016-09-30 23:59:27+00:00 2016-10-01 00:08:40+00:00
# 3          1584 2016-09-30 23:59:17+00:00 2016-10-01 00:25:42+00:00
# 4           652 2016-09-30 23:59:12+00:00 2016-10-01 00:10:04+00:00
# 5           547 2016-09-30 23:59:11+00:00 2016-10-01 00:08:19+00:00
# 6           627 2016-09-30 23:58:55+00:00 2016-10-01 00:09:22+00:00
# 7           411 2016-09-30 23:58:40+00:00 2016-10-01 00:05:32+00:00
# 8           502 2016-09-30 23:58:24+00:00 2016-10-01 00:06:47+00:00
# 9          3104 2016-09-30 23:58:18+00:00 2016-10-01 00:50:03+00:00
#
#    start_station_id            start_station_name  start_station_latitude  \
# 0              2002  Wythe Ave & Metropolitan Ave               40.716887
# 1              2002  Wythe Ave & Metropolitan Ave               40.716887
# 2               157       Henry St & Atlantic Ave               40.690893
# 3               229                Great Jones St               40.727434
# 4               438           St Marks Pl & 1 Ave               40.727791
# 5               157       Henry St & Atlantic Ave               40.690893
# 6              3158            W 63 St & Broadway               40.771639
# 7               323   Lawrence St & Willoughby St               40.692362
# 8              3409          Bergen St & Smith St               40.686744
# 9              3146               E 81 St & 3 Ave               40.775730
#
#    start_station_longitude  end_station_id             end_station_name  \
# 0               -73.963198             418           Front St & Gold St
# 1               -73.963198             418           Front St & Gold St
# 2               -73.996123            3429       Hanson Pl & Ashland Pl
# 3               -73.993790            3100       Nassau Ave & Newell St
# 4               -73.985649             434              9 Ave & W 18 St
# 5               -73.996123            3429       Hanson Pl & Ashland Pl
# 6               -73.982614            3314           W 95 St & Broadway
# 7               -73.986317             258  DeKalb Ave & Vanderbilt Ave
# 8               -73.990632            3368                 5 Ave & 3 St
# 9               -73.956753            3402          Court St & State St
#
#    end_station_latitude  end_station_longitude  bikeid    usertype  \
# 0             40.702240             -73.982578   22300  Subscriber
# 1             40.702240             -73.982578   22896  Subscriber
# 2             40.685068             -73.977908   18868  Subscriber
# 3             40.724813             -73.947526   23654  Subscriber
# 4             40.743174             -74.003664   22770  Subscriber
# 5             40.685068             -73.977908   17656  Subscriber
# 6             40.793770             -73.971888   25225  Subscriber
# 7             40.689407             -73.968855   27314  Subscriber
# 8             40.672815             -73.983524   27269  Subscriber
# 9             40.690238             -73.992031   22156  Subscriber
#
#    birth_year  gender
# 0        1982    male
# 1        1989  female
# 2        1970    male
# 3        1981    male
# 4        1989    male
# 5        1974    male
# 6        1990    male
# 7        1971    male
# 8        1977    male
# 9        1986    male
