# %%
import pandas_gbq

sql_stations = """
select *
from `bigquery-public-data.new_york.citibike_stations`
LIMIT 10
"""
stations = pandas_gbq.read_gbq(sql_stations)

sql_trips = """
SELECT * 
FROM `bigquery-public-data.new_york.citibike_trips` 
LIMIT 1000
"""
trips = pandas_gbq.read_gbq(sql_trips)
# Out:
# Running cells with '/Users/juan-garassino/.pyenv/versions/3.10.6/bin/python' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/Users/juan-garassino/.pyenv/versions/3.10.6/bin/python -m pip install ipykernel -U --force-reinstall'

# %%
trips.head(3)

# %%
trips.start_station_id.unique()
