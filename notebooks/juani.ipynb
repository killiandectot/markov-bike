# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from markovBike.source.source import database_queries, get_stations_data, get_trips_data

# %%
database_queries(12)
# Out:
# {'stations': 'SELECT * FROM bigquery-public-data.new_york.citibike_stations LIMIT 12',
#  'trips': 'SELECT * FROM bigquery-public-data.new_york.citibike_trips LIMIT 12'}

# %%
data = get_stations_data(database_queries(12)['stations'])

# %%
data.values.tolist()
# Out:
# [['495',
#   'W 47 St & 10 Ave',
#   '6824.07',
#   40.76269882,
#   -73.99301222,
#   71,
#   'KEY, CREDITCARD',
#   0,
#   False,
#   0,
#   0,
#   0,
#   0,
#   True,
#   True,
#   True,
#   False,
#   Timestamp('1970-01-02 00:00:00+0000', tz='UTC')],
#  ['3171',
#   'Amsterdam Ave & W 82 St',
#   '7360.10',
#   40.78524672,
#   -73.97667321,
#   71,
#   'KEY, CREDITCARD',
#   0,
#   False,
#   0,
#   0,
#   0,
#   0,
#   False,
#   False,
#   False,
#   False,
#   Timestamp('1970-01-02 00:00:00+0000', tz='UTC')],
#  ['3603',
#   '31 Ave & 30 St',
#   '6857.09',
#   40.7647,
#   -73.9240312,
#   71,
#   'KEY, CREDITCARD',
#   0,
#   False,
#   0,
#   0,
#   0,
#   0,
#   False,
#   False,
#   False,
#   False,
#   Timestamp('1970-01-02 00:00:00+0000', tz='UTC')],
#  ['3733',
#   'Avenue C & E 18 St',
#   '5769.04',
#   40.730563,
#   -73.973984,
#   71,
#   'KEY, CREDITCARD',
#   0,
#   False,
#   0,
#   0,
#   0,
#   0,
#   False,
#   False,
#   False,
#   False,
# ...

# %%
trips = get_stations_data(database_queries(12)['trips'])
# Out:
# Bike stations table with 12 samples and 15 columns loaded, columns are:
#
# tripduration                             Int64
# starttime                  datetime64[ns, UTC]
# stoptime                   datetime64[ns, UTC]
# start_station_id                         Int64
# start_station_name                      object
# start_station_latitude                 float64
# start_station_longitude                float64
# end_station_id                           Int64
# end_station_name                        object
# end_station_latitude                   float64
# end_station_longitude                  float64
# bikeid                                   Int64
# usertype                                object
# birth_year                               Int64
# gender                                  object
# dtype: object
